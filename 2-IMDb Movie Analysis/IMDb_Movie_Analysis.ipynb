# %% [markdown]
# ### Project Setup & Import Dataset

# %%
# Importing Libraries
# !pip install pandas numpy
# !pip install seaborn
# !pip install matplotlib
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\users\devansh\appdata\roaming\python\python311\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\devansh\appdata\roaming\python\python311\site-packages (2.3.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: seaborn in c:\users\devansh\appdata\roaming\python\python311\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from seaborn) (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\devansh\appdata\roaming\python\python311\site-packages (3.10.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\devansh\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# Import CSV
df = pd.read_csv("G:/30 Data Analyst/2-IMDb Movie Analysis/imdb_movies.csv")
df.head(10)
# Out:
#                           names       date_x  score  \
# 0                     Creed III  03/02/2023    73.0
# 1      Avatar: The Way of Water  12/15/2022    78.0
# 2   The Super Mario Bros. Movie  04/05/2023    76.0
# 3                       Mummies  01/05/2023    70.0
# 4                     Supercell  03/17/2023    61.0
# 5                  Cocaine Bear  02/23/2023    66.0
# 6          John Wick: Chapter 4  03/23/2023    80.0
# 7  Puss in Boots: The Last Wish  12/26/2022    83.0
# 8               Attack on Titan  09/30/2022    59.0
# 9                      The Park  03/02/2023    58.0
#
#                                               genre  \
# 0                                     Drama, Action
# 1                Science Fiction, Adventure, Action
# 2     Animation, Adventure, Family, Fantasy, Comedy
# 3     Animation, Comedy, Family, Adventure, Fantasy
# 4                                            Action
# 5                           Thriller, Comedy, Crime
# 6                           Action, Thriller, Crime
# 7     Animation, Family, Fantasy, Adventure, Comedy
# 8                           Action, Science Fiction
# 9  Action, Drama, Horror, Science Fiction, Thriller
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
# 5  Inspired by a true story, an oddball group of ...
# 6  With the price on his head ever increasing, Jo...
# 7  Puss in Boots discovers that his passion for a...
# 8  As viable water is depleted on Earth, a missio...
# 9  A dystopian coming-of-age movie focused on thr...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
# 5  Keri Russell, Sari, Alden Ehrenreich, Eddie, O...
# 6  Keanu Reeves, John Wick, Donnie Yen, Caine, Bi...
# 7  Antonio Banderas, Puss in Boots (voice), Salma...
# 8  Paul Bianchi, Computer (voice), Erin Coker, Al...
# 9  Chloe Guidry, Ines, Nhedrick Jabier, Bui, Carm...
#
#                      orig_title     status            orig_lang     budget_x  \
# 0                     Creed III   Released              English   75000000.0
# 1      Avatar: The Way of Water   Released              English  460000000.0
# 2   The Super Mario Bros. Movie   Released              English  100000000.0
# 3                        Momias   Released   Spanish, Castilian   12300000.0
# 4                     Supercell   Released              English   77000000.0
# 5                  Cocaine Bear   Released              English   35000000.0
# 6          John Wick: Chapter 4   Released              English  100000000.0
# 7  Puss in Boots: The Last Wish   Released              English   90000000.0
# 8               Attack on Titan   Released              English   71000000.0
# 9                      The Park   Released              English  119200000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US
# 5  8.000000e+07      AU
# 6  3.513494e+08      AU
# 7  4.834806e+08      AU
# 8  2.549465e+08      US
# 9  4.889625e+08      US

# %%
df.shape
# Out:
# (10178, 12)

# %%
# sort movies from highest to lowest in revenue
df.sort_values(by = 'revenue', ascending=False).head(10)
# Out:
#                                      names       date_x  score  \
# 68                                  Avatar  12/17/2009    76.0
# 230                      Avengers: Endgame  04/24/2019    83.0
# 1                 Avatar: The Way of Water  12/15/2022    78.0
# 309                                Titanic  12/18/1997    79.0
# 6670                               Titanic  04/11/1953    66.0
# 4483  Louis Tomlinson: All of Those Voices  03/22/2023    91.0
# 943           Star Wars: The Force Awakens  12/17/2015    73.0
# 104                 Avengers: Infinity War  04/25/2018    83.0
# 5683                         Rathinirvedam  03/08/1978    95.0
# 76                 Spider-Man: No Way Home  12/16/2021    80.0
#
#                                             genre  \
# 68    Action, Adventure, Fantasy, Science Fiction
# 230            Adventure, Science Fiction, Action
# 1              Science Fiction, Adventure, Action
# 309                                Drama, Romance
# 6670                               Drama, Romance
# 4483                           Documentary, Music
# 943   Adventure, Action, Science Fiction, Fantasy
# 104            Adventure, Action, Science Fiction
# 5683                                          NaN
# 76             Action, Adventure, Science Fiction
#
#                                                overview  \
# 68    In the 22nd century, a paraplegic Marine is di...
# 230   After the devastating events of Avengers: Infi...
# 1     Set more than a decade after the events of the...
# 309   101-year-old Rose DeWitt Bukater tells the sto...
# 6670  Unhappily married, Julia Sturges decides to go...
# 4483  Ditching the typical glossy sheen of celebrity...
# 943   Thirty years after defeating the Galactic Empi...
# 104   As the Avengers and their allies have continue...
# 5683  The story takes place in a small village surro...
# 76    Peter Parker is unmasked and no longer able to...
#
#                                                    crew  \
# 68    Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 230   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 1     Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 309   Leonardo DiCaprio, Jack Dawson, Kate Winslet, ...
# 6670  Clifton Webb, Richard Ward Sturges, Barbara St...
# 4483  Louis Tomlinson, Self, Oliver Wright, Louis’ P...
# 943   Harrison Ford, Han Solo, Mark Hamill, Luke Sky...
# 104   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 5683  Jayabharathi, Rathi, Krishnachandran, Pappu, K...
# 76    Tom Holland, Peter Parker / Spider-Man, Zenday...
#
#                                 orig_title     status   orig_lang  \
# 68                                  Avatar   Released     English
# 230                      Avengers: Endgame   Released     English
# 1                 Avatar: The Way of Water   Released     English
# 309                                Titanic   Released     English
# 6670                               Titanic   Released     English
# 4483  Louis Tomlinson: All of Those Voices   Released     English
# 943           Star Wars: The Force Awakens   Released     English
# 104                 Avengers: Infinity War   Released     English
# 5683                         Rathinirvedam   Released   Malayalam
# 76                 Spider-Man: No Way Home   Released     English
#
#          budget_x       revenue country
# 68    237000000.0  2.923706e+09      AU
# 230   400000000.0  2.794732e+09      AU
# 1     460000000.0  2.316795e+09      AU
# 309   200000000.0  2.222986e+09      AU
# 6670  200000000.0  2.222986e+09      US
# 4483  178800000.0  2.081794e+09      GB
# 943   245000000.0  2.068224e+09      AU
# 104   300000000.0  2.048360e+09      AU
# 5683  227800000.0  1.916347e+09      IN
# 76    200000000.0  1.910048e+09      AU

# %% [markdown]
# ### Data Overview and Exploratory data analysis

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  object
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  float64
#  10  revenue     10178 non-null  float64
#  11  country     10178 non-null  object
# dtypes: float64(3), object(9)
# memory usage: 954.3+ KB
# names          0
# date_x         0
# score          0
# genre         85
# overview       0
# crew          56
# orig_title     0
# status         0
# orig_lang      0
# budget_x       0
# revenue        0
# country        0
# dtype: int64

# %%
df.nunique()
# Out:
# names         9660
# date_x        5688
# score           79
# genre         2303
# overview      9905
# crew          9927
# orig_title    9736
# status           3
# orig_lang       54
# budget_x      2316
# revenue       8227
# country         60
# dtype: int64

# %%
df.describe()
# Out:
#               score      budget_x       revenue
# count  10178.000000  1.017800e+04  1.017800e+04
# mean      63.497052  6.488238e+07  2.531401e+08
# std       13.537012  5.707565e+07  2.777880e+08
# min        0.000000  1.000000e+00  0.000000e+00
# 25%       59.000000  1.500000e+07  2.858898e+07
# 50%       65.000000  5.000000e+07  1.529349e+08
# 75%       71.000000  1.050000e+08  4.178021e+08
# max      100.000000  4.600000e+08  2.923706e+09

# %%
df['date_x']=pd.to_datetime(df['date_x'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10178 entries, 0 to 10177
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   names       10178 non-null  object
#  1   date_x      10178 non-null  datetime64[ns]
#  2   score       10178 non-null  float64
#  3   genre       10093 non-null  object
#  4   overview    10178 non-null  object
#  5   crew        10122 non-null  object
#  6   orig_title  10178 non-null  object
#  7   status      10178 non-null  object
#  8   orig_lang   10178 non-null  object
#  9   budget_x    10178 non-null  float64
#  10  revenue     10178 non-null  float64
#  11  country     10178 non-null  object
# dtypes: datetime64[ns](1), float64(3), object(8)
# memory usage: 954.3+ KB

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [names, date_x, score, genre, overview, crew, orig_title, status, orig_lang, budget_x, revenue, country]
# Index: []

# %%
# Fill the null values in 'genre' and 'crew' column with 'N/A'

df['genre'] = df['genre'].fillna('N/A')
df['crew'] = df['crew'].fillna('N/A')

df.isnull().sum()
# Out:
# names         0
# date_x        0
# score         0
# genre         0
# overview      0
# crew          0
# orig_title    0
# status        0
# orig_lang     0
# budget_x      0
# revenue       0
# country       0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### General Analysis

# %%
# How many movies are released, In Production and Post Production?
ax = sns.countplot(x='status',data = df)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
df.head()
# Out:
#                          names     date_x  score  \
# 0                    Creed III 2023-03-02   73.0
# 1     Avatar: The Way of Water 2022-12-15   78.0
# 2  The Super Mario Bros. Movie 2023-04-05   76.0
# 3                      Mummies 2023-01-05   70.0
# 4                    Supercell 2023-03-17   61.0
#
#                                            genre  \
# 0                                  Drama, Action
# 1             Science Fiction, Adventure, Action
# 2  Animation, Adventure, Family, Fantasy, Comedy
# 3  Animation, Comedy, Family, Adventure, Fantasy
# 4                                         Action
#
#                                             overview  \
# 0  After dominating the boxing world, Adonis Cree...
# 1  Set more than a decade after the events of the...
# 2  While working underground to fix a water main,...
# 3  Through a series of unfortunate events, three ...
# 4  Good-hearted teenager William always lived in ...
#
#                                                 crew  \
# 0  Michael B. Jordan, Adonis Creed, Tessa Thompso...
# 1  Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 2  Chris Pratt, Mario (voice), Anya Taylor-Joy, P...
# 3  Óscar Barberán, Thut (voice), Ana Esther Albor...
# 4  Skeet Ulrich, Roy Cameron, Anne Heche, Dr Quin...
#
#                     orig_title     status            orig_lang     budget_x  \
# 0                    Creed III   Released              English   75000000.0
# 1     Avatar: The Way of Water   Released              English  460000000.0
# 2  The Super Mario Bros. Movie   Released              English  100000000.0
# 3                       Momias   Released   Spanish, Castilian   12300000.0
# 4                    Supercell   Released              English   77000000.0
#
#         revenue country
# 0  2.716167e+08      AU
# 1  2.316795e+09      AU
# 2  7.244590e+08      AU
# 3  3.420000e+07      AU
# 4  3.409420e+08      US

# %%
df[(df['genre'].str.contains('Science Fiction')) | ((df['status']=='released') & (df['country']=='US'))].sort_values(by ='revenue',ascending = False)
# Out:
#                              names     date_x  score  \
# 68                          Avatar 2009-12-17   76.0
# 230              Avengers: Endgame 2019-04-24   83.0
# 1         Avatar: The Way of Water 2022-12-15   78.0
# 943   Star Wars: The Force Awakens 2015-12-17   73.0
# 104         Avengers: Infinity War 2018-04-25   83.0
# ...                            ...        ...    ...
# 2886                      Bird Box 2018-12-21   69.0
# 4350                  Artemis Fowl 2020-06-12   56.0
# 4091                   How It Ends 2018-07-13   53.0
# 4041                    Sky Sharks 2021-08-26   50.0
# 4431        Independence Daysaster 2013-06-27   46.0
#
#                                                   genre  \
# 68          Action, Adventure, Fantasy, Science Fiction
# 230                  Adventure, Science Fiction, Action
# 1                    Science Fiction, Adventure, Action
# 943         Adventure, Action, Science Fiction, Fantasy
# 104                  Adventure, Action, Science Fiction
# ...                                                 ...
# 2886                   Thriller, Drama, Science Fiction
# 4350  Adventure, Fantasy, Science Fiction, Family, A...
# 4091  Science Fiction, Thriller, Mystery, Action, Ad...
# 4041                    Horror, Science Fiction, Comedy
# 4431                            Action, Science Fiction
#
#                                                overview  \
# 68    In the 22nd century, a paraplegic Marine is di...
# 230   After the devastating events of Avengers: Infi...
# 1     Set more than a decade after the events of the...
# 943   Thirty years after defeating the Galactic Empi...
# 104   As the Avengers and their allies have continue...
# ...                                                 ...
# 2886  Five years after an ominous unseen presence dr...
# 4350  Artemis Fowl is a 12-year-old genius and desce...
# 4091  A desperate father tries to return home to his...
# 4041  A team of Arctic geologists stumble across an ...
# 4431  When Earth is attacked by a hostile alien forc...
#
#                                                    crew  \
# 68    Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 230   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# 1     Sam Worthington, Jake Sully, Zoe Saldaña, Neyt...
# 943   Harrison Ford, Han Solo, Mark Hamill, Luke Sky...
# 104   Robert Downey Jr., Tony Stark / Iron Man, Chri...
# ...                                                 ...
# 2886  Sandra Bullock, Malorie Hayes, Trevante Rhodes...
# 4350  Ferdia Shaw, Artemis Fowl II, Colin Farrell, A...
# 4091  Theo James, Will, Forest Whitaker, Tom, Kat Gr...
# 4041  Barbara Nedeljakova, Angelique, Eva Habermann,...
# 4431  Casey Dubois, Nick Miller, Iain Belcher, Todd,...
#
#                         orig_title     status orig_lang     budget_x  \
# 68                          Avatar   Released   English  237000000.0
# 230              Avengers: Endgame   Released   English  400000000.0
# 1         Avatar: The Way of Water   Released   English  460000000.0
# 943   Star Wars: The Force Awakens   Released   English  245000000.0
# 104         Avengers: Infinity War   Released   English  300000000.0
# ...                            ...        ...       ...          ...
# 2886                      Bird Box   Released   English   19800000.0
# 4350                  Artemis Fowl   Released   English  100000000.0
# 4091                   How It Ends   Released   English   20000000.0
# 4041                    Sky Sharks   Released   English    2500000.0
# 4431        Independence Daysaster   Released   English    1800000.0
#
#            revenue country
# 68    2.923706e+09      AU
# 230   2.794732e+09      AU
# 1     2.316795e+09      AU
# 943   2.068224e+09      AU
# 104   2.048360e+09      AU
# ...            ...     ...
# 2886  0.000000e+00      AU
# 4350  0.000000e+00      AU
# 4091  0.000000e+00      US
# 4041  0.000000e+00      DE
# 4431  0.000000e+00      US
#
# [1261 rows x 12 columns]

# %%
df.score.unique()
# Out:
# array([ 73.,  78.,  76.,  70.,  61.,  66.,  80.,  83.,  59.,  58.,  55.,
#         65.,  72.,  62.,  64.,  57.,  69.,  74.,  53.,  71.,  63.,  60.,
#         54.,  52.,  81.,  68.,  79.,  67.,  47.,  82.,  43.,  56.,  75.,
#          0.,  77.,  84.,  49.,  46.,  30., 100.,  48.,  86.,  85.,  50.,
#         87.,  37.,  34.,  20.,  38.,  35.,  36.,  44.,  51.,  45.,  40.,
#         27.,  10.,  22.,  90.,  42.,  25.,  92.,  33.,  28.,  29.,  41.,
#         15.,  39.,  32.,  16.,  17.,  23.,  91.,  93.,  95.,  13.,  26.,
#         98.,  18.])

# %%
df.score.value_counts()
# Out:
# score
# 68.0    474
# 65.0    445
# 69.0    437
# 63.0    433
# 66.0    421
#        ...
# 92.0      1
# 29.0      1
# 28.0      1
# 22.0      1
# 18.0      1
# Name: count, Length: 79, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['score'],bins =20, kde=True, color = 'Yellow')
plt.title('Distribution of Movie Scores')
plt.xlabel('Score')
plt.savefig('Images/Distribution of Movie Scores.jpg')
plt.show()

# %% [markdown]
# ### 2. What is the most common genres in the IMDB? Use a bar chart to show their distribution.

# %%
# Aggregate data of genre with total count of movies
gb = df.groupby('genre').agg({'names':'count'})
gb = gb.sort_values(by = 'names', ascending = False)
gb = gb.head(20)

# %%
plt.figure(figsize = (10, 6))
sns.barplot(x = gb.index, y = gb['names'], data = gb, palette = 'rocket')
plt.ylabel('Count of Movies')
plt.xlabel('Genre')
plt.title('Common Genres')
plt.xticks(rotation = 90)
plt.savefig('Images/Common Genre.jpg')
plt.show()
# Out:
# C:\Users\Devansh\AppData\Local\Temp\ipykernel_11076\259646732.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = gb.index, y = gb['names'], data = gb, palette = 'rocket')

# %% [markdown]
# ## Bivariate Analysis
# ### 1. Is there any relationship between a movie's budget and its revenue? Plot a scatter plot and describe any observed trend

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='budget_x', y = 'revenue', data=df, color ='black')
plt.title('Revenue vs Budget')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.savefig('Images/Revenue-Budget.jpg')
plt.show()

# %% [markdown]
# ### 2.How do scores vary by country? Use a boxplot to visualize the difference in scores across country.

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x='country',  y='score', data=df, color = 'orange')
plt.title('Score vs Country')
plt.xlabel('Country')
plt.ylabel('Score')
plt.xticks(rotation = 90)
plt.savefig('Images/Country-Score.jpg')
plt.show()

# %%
# Create a dataframe to store score, budget and revenue, and find its correlation.
df1 = df[['score','budget_x','revenue']]
df1.columns = ['Score','Budget','Revenue']

df1.head()
# Out:
#    Score       Budget       Revenue
# 0   73.0   75000000.0  2.716167e+08
# 1   78.0  460000000.0  2.316795e+09
# 2   76.0  100000000.0  7.244590e+08
# 3   70.0   12300000.0  3.420000e+07
# 4   61.0   77000000.0  3.409420e+08

# %%
corr = df1.corr()
corr
# Out:
#             Score   Budget   Revenue
# Score    1.000000 -0.23547  0.096533
# Budget  -0.235470  1.00000  0.673830
# Revenue  0.096533  0.67383  1.000000

# %%
sns.heatmap(corr, annot = True)
plt.show()

# %% [markdown]
# ### Is there a significant relationship between high IMDB scores and box office success?

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x='score', y = 'revenue', data=df, color ='purple')
plt.title('Revenue vs Score')
plt.ylabel('Revenue')
plt.xlabel('Score')
plt.savefig('Images/Revenue-Score.jpg')
plt.show()

# %% [markdown]
# ## Genre-Specific Analysis
# ### 1. Which genre has the highest average score? Calculate the average score for each genre and plot the results.

# %%
gb1 = df.groupby('genre').agg({'score':'mean'})
gb1 = gb1.sort_values(by='score',ascending = False)
gb1 = gb1.head()

# %%
gb1
# Out:
#                                                     score
# genre
# Fantasy, Drama, Crime                           85.000000
# Adventure, Animation, Comedy, Fantasy, Mystery  85.000000
# Romance, Animation, Drama                       85.000000
# Animation, Comedy, Romance                      84.666667
# Animation, Family, Fantasy, Adventure, Comedy   83.000000

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=gb1.index, y= gb1['score'],data = gb1, palette='cubehelix')
plt.title('Average Score vs Genre')
plt.xlabel('Genre')
plt.ylabel('Average Score')
plt.xticks(rotation = 90)
plt.savefig('Images/Average Score-Genre.jpg')
plt.show()
# Out:
# C:\Users\Devansh\AppData\Local\Temp\ipykernel_11076\279632673.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=gb1.index, y= gb1['score'],data = gb1, palette='cubehelix')

# %% [markdown]
# ### How does the popularity of genres vary over time? Plot the number of movies released per genre each year.

# %%
# Extract year from data_x column

df['year'] = df['date_x'].dt.strftime('%Y')
df['year'] = df['year'].astype(int)
df['year']
# Out:
# 0        2023
# 1        2022
# 2        2023
# 3        2023
# 4        2023
#          ...
# 10173    2016
# 10174    1990
# 10175    1990
# 10176    1995
# 10177    2020
# Name: year, Length: 10178, dtype: int64

# %%
#Group year and genre and count number of movie released each year in each group

gb2 = df.groupby(['year','genre']).size().reset_index(name='count')
gb2 = gb2.head(15)

# %%
# Plot the data
plt.figure(figsize=(12,6))
sns.barplot(x='year',y='count',hue='genre', data = gb2, palette = 'Spectral')
plt.title('Count of Movies Per Genre Each Year')
plt.xlabel('Year')
plt.ylabel('Count of Movies')
plt.xticks(rotation = 90)
plt.legend(title='Genre',bbox_to_anchor = (1.05,1),loc = 'upper left')
plt.savefig('Images/Count of Movies Per Genre Each Year.jpg')
plt.show()

# %% [markdown]
# ## Year and Trend Analysis
# ### 1. How has the average score changed over the years? Plot the average score for each year.

# %%
average_score  = df.groupby('year').agg({'score':'mean'})
average_score
# Out:
#           score
# year
# 1903  63.000000
# 1907  80.000000
# 1915  61.000000
# 1920  80.000000
# 1923  71.666667
# ...         ...
# 2019  64.263830
# 2020  64.220490
# 2021  66.057416
# 2022  64.370021
# 2023  39.456576
#
# [99 rows x 1 columns]

# %%
plt.figure(figsize = (12,6))
sns.barplot(x=average_score.index, y = average_score['score'], data = average_score, palette = 'rainbow')
plt.title('Average Score over Years')
plt.xlabel('Year')
plt.ylabel('Average Score')
plt.xticks(rotation = 90, fontsize=6)
plt.savefig('Images/Average Score over Years.jpg')
plt.show()
# Out:
# C:\Users\Devansh\AppData\Local\Temp\ipykernel_11076\409245216.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=average_score.index, y = average_score['score'], data = average_score, palette = 'rainbow')

# %% [markdown]
# ### 2. Which years had the highest and lowest number of movie releases? Plot the number of movies released each year.

# %%
movies_count = df.groupby('year').agg({'names':'count'})
movies_count.tail(10)
# Out:
#       names
# year
# 2014    343
# 2015    350
# 2016    389
# 2017    434
# 2018    469
# 2019    470
# 2020    449
# 2021    627
# 2022    954
# 2023    403

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = movies_count.index, y = movies_count['names'], data = movies_count, palette = 'plasma')
plt.title('Count of Movies Released')
plt.xlabel('Year')
plt.ylabel('Number of Movie Released each Year')
plt.xticks(rotation =90, fontsize = 6)
plt.savefig('Images/ Movies Released Each Year.jpg')
plt.show()
# Out:
# C:\Users\Devansh\AppData\Local\Temp\ipykernel_11076\174108436.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x = movies_count.index, y = movies_count['names'], data = movies_count, palette = 'plasma')

# %%
# Which year has the highest and lowest movie release

year_count = df.year.value_counts()
year_count
# Out:
# year
# 2022    954
# 2021    627
# 2019    470
# 2018    469
# 2020    449
#        ...
# 1930      1
# 1907      1
# 1949      1
# 1920      1
# 1903      1
# Name: count, Length: 99, dtype: int64

# %%
max_row = movies_count.loc[movies_count['names']== movies_count['names'].max()]
highest_release_year = max_row.index[0]


min_row = movies_count.loc[movies_count['names'] == movies_count['names'].min()]
lowest_release_year = min_row.index[0]

print(highest_release_year,',',lowest_release_year)
# Out:
# 2022 , 1903

# %% [markdown]
# ### 3. Plot the number of movies released each decade

# %%
df['decade'] = df['year'] // 10 * 10

# %%
df['decade'].unique()
# Out:
# array([2020, 2000, 2010, 1990, 1950, 1980, 1970, 1960, 1900, 1930, 1940,
#        1920, 1910])

# %%
decade = df.groupby('decade').agg({'genre':'count'})
decade
# Out:
#         genre
# decade
# 1900        2
# 1910        2
# 1920       10
# 1930       22
# 1940       35
# 1950       78
# 1960      141
# 1970      284
# 1980      629
# 1990     1057
# 2000     1932
# 2010     3553
# 2020     2433

# %%
plt.figure(figsize =(10,6))
sns.barplot(x= decade.index, y = decade['genre'],data = decade, palette = 'autumn')
plt.title('Movie Released Each Decade')
plt.xlabel('Year')
plt.ylabel('Count of Movie Released')
plt.xticks(rotation = 90)
plt.savefig('Images/Movies Released Each Decade.jpg')
plt.show()
# Out:
# C:\Users\Devansh\AppData\Local\Temp\ipykernel_11076\774581535.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x= decade.index, y = decade['genre'],data = decade, palette = 'autumn')

# %% [markdown]
# ## Summary
#
# ### Based on this practical what 3 major insights we get/learned about movies trends, popular genres, or movie score?
# **Seasonal release trends and score** : Movies release during holidays or summer season tends to have higher box office earnings and more audience ratings.
#
# **Genre Popularity Over Time** : Certain genres, such as action and adventure, have seen a consistent rise in popularity over the years, like driven by advancements in special effects and global box office appeal. In contrast, genre like westerns or musicals have experienced a decline, possibly due to chnage in audience preferences and cultural trends.
#
# **Impact of Budget on Movie Scores**: High budget movees often perform better in terms of audience and critic rating, as they can invest in better visual effects, renomved directors and top-tier actos. However, there are exceptions with some low-budget films (eg: independent dramas or thrillers) achieving critical acclaim due to strong storytelling and innovative filmmaking.
